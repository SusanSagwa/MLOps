# %%
#Create a script that adds two numeric user inputs and prints output

addition = 25 + 12
print(addition)
# Out:
# 37

# %%
#Use f-strings and input variables to print a customized greeting

name = "Lockheart"
print(f"Hello {name}, hope you are having a great day!")
# Out:
# Hello Lockheart, hope you are having a great day!

# %%
#Catch a ZeroDivisionError to print a user-friendly error message
try:
    # some intense operation that causes an error
    result = 14 / 0 
except ZeroDivisionError:
    # do some other intense operation
    result = 14 / 2

print(result)
# Out:
# 7.0
